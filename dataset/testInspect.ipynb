# %% [markdown]
# requirements
# as the kernel was not responding to my commands

# %%
# import sys
# !{sys.executable} -m pip uninstall tensorflow -y
# !{sys.executable} -m pip install tensorflow

# import sys
# !{sys.executable} -m pip install scikit-learn
# pip install numpy

# %% [markdown]
# main job

# %%
import pandas as pd
df = pd.read_csv("smart_grid_stability_augmented.csv")

print(df.head())
print(df.info())
print(df.describe())

# %%
print(df.isnull().sum())

# %%
from sklearn.model_selection import train_test_split

# %%
# Out:
# Requirement already satisfied: numpy in c:\users\shiva\appdata\local\programs\python\python313\lib\site-packages (2.3.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
